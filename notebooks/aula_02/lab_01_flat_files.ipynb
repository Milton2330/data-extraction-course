# %% [markdown]
# # Lab 02 - Extração de Dados: Arquivos Planos
# **Disciplina:** Extração e Preparação de Dados | **Professor:** Luis Aramis
#
# Neste laboratório, vamos praticar a leitura de diferentes formatos de arquivos planos (CSV, Excel) e lidar com problemas comuns como codificação, delimitadores e metadados.

# %% [markdown]
# ## 1. Setup
# Importe a biblioteca pandas.

# %%
# Seu código aqui
import pandas as pd

# %% [markdown]
# ## 2. CSV Padrão
# Carregue o arquivo `vendas.csv` e exiba as 5 primeiras linhas.

# %%
# Seu código aqui
import pandas as pd

df_vendas = pd.read_csv("../../data/aula_02/vendas.csv")
df_vendas.head()
# Out:
#    id_venda        data   produto  quantidade  preco_unitario     total
# 0         1  2024-01-01   Teclado           1         2852.92   2852.92
# 1         2  2024-01-02   Teclado           7         3249.47  22746.29
# 2         3  2024-01-03   Teclado           7         4104.96  28734.72
# 3         4  2024-01-04   Teclado           1          870.74    870.74
# 4         5  2024-01-05  Notebook           7         3614.27  25299.89

# %% [markdown]
# ## 3. CSV com Problemas (Delimitador e Encoding)
# Tente carregar o arquivo `produtos_brasil.csv`.
# Você encontrará erros. Corrija utilizando os parâmetros `sep` e `encoding`.
# Obs: O separador é `;` e o encoding é `latin1`.

# %%
# Seu código aqui
import pandas as pd

df_produtos = pd.read_csv("../../data/aula_02/produtos_brasil.csv",sep=";",encoding="latin1")

df_produtos.head()
# Out:
#     id           nome preco_reais
# 0  101           Café       32,75
# 1  102         Feijão       49,96
# 2  103  Pão de Queijo       32,98
# 3  104           Açaí        6,24
# 4  105        Guaraná       19,24

# %% [markdown]
# ## 4. Excel com Múltiplas Abas
# Carregue a aba 'Jan' do arquivo `relatorio_financeiro.xlsx`.
# Observe que o cabeçalho não está na primeira linha. Use o parâmetro `header` ou `skiprows` para corrigir.

# %%
# Seu código aqui
import pandas as pd

df_jan = pd.read_excel(
    "../../data/aula_02/relatorio_financeiro.xlsx",
    sheet_name="Jan",
    skiprows=3
)

df_jan.head()
# Out:
#    Dia  Receita
# 0    1     4475
# 1    2     2561
# 2    3     4247
# 3    4     3347
# 4    5     2334

# %% [markdown]
# ## 5. Delimitadores Exóticos
# Carregue o arquivo `movies.csv`. Ele usa o caractere `|` como separador.

# %%
# Seu código aqui
import pandas as pd

df_movies = pd.read_csv("../../data/aula_02/movies.csv", sep="|")
df_movies.head()
# Out:
#    movie_id         title  year
# 0         1     Inception  2010
# 1         2    The Matrix  1999
# 2         3  Interstellar  2014
# 3         4      Parasite  2019
# 4         5      Avengers  2012

# %% [markdown]
# ## 6. Arquivos com Metadados no Início
# O arquivo `ibge_metadata.csv` possui 3 linhas de texto antes do cabeçalho real.
# Use o parâmetro `skiprows` para ignorá-las. Dica: encoding `cp1252`.

# %%
# Seu código aqui
import pandas as pd

df_ibge = pd.read_csv(
    "../../data/aula_02/ibge_metadata.csv",
    skiprows=3,
    encoding="cp1252"
)

df_ibge.head()
# Out:
#    cod_municipio  nome_municipio  populacao_estimada
# 0        3550308       São Paulo            11451245
# 1        3304557  Rio de Janeiro             6211423
# 2        3106200  Belo Horizonte             2438423

# %% [markdown]
# ---
# ## PARTE 2: APROFUNDAMENTO
# Tratamento de Arquivos Massivos e Múltiplos Arquivos.

# %% [markdown]
# ## 7. Leitura em Chunks (Big Files)
# O arquivo `big_file.csv` simula um arquivo grande. Leia-o em pedaços (chunks) de 10.000 linhas e exiba o tipo do objeto resultante.

# %%
# Seu código aqui
import pandas as pd

chunks = pd.read_csv("../../data/aula_02/big_file.csv", chunksize=10000)

print(type(chunks))
# Out:
# <class 'pandas.io.parsers.readers.TextFileReader'>

# %% [markdown]
# ## 8. Linhas com Erro (Bad Lines)
# O arquivo `bad_lines.csv` possui linhas quebradas. Tente carregar ignorando as linhas com erro utilizando `on_bad_lines`.

# %%
# Seu código aqui
import pandas as pd

df_bad = pd.read_csv(
    "../../data/aula_02/bad_lines.csv",
    on_bad_lines="skip"
)

df_bad.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 4
#       1 # Seu código aqui
#       2 import pandas as pd
# ----> 4 df_bad = pd.read_csv(
#       5     "../../data/aula_02/bad_lines.csv",
#       6     on_bad_lines="skip"
#       7 )
#       9 df_bad.head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/aula_02/bad_lines.csv'

# %% [markdown]
# ## 9. Múltiplos Arquivos (Glob)
# Use a biblioteca `glob` para listar os arquivos na pasta `batch_data/` e carregá-los em um único DataFrame com `pd.concat`.

# %%
import pandas as pd
import glob

arquivos = glob.glob("../../data/aula_02/batch_data/*.csv")
print(arquivos)
# Out:
# ['../../data/aula_02/batch_data\\bad_lines.csv', '../../data/aula_02/batch_data\\big_file.csv']

# %% [markdown]
# ---
# ## PARTE 3: NÍVEL EXPERT
# Otimização e Limpeza Avançada.

# %% [markdown]
# ## 10. Otimização de Memória (Downcasting)
# 1. Carregue o arquivo `big_file.csv` inteiro (se couber) ou um chunk.
# 2. Verifique o uso de memória com `.info(memory_usage='deep')`.
# 3. Converta uma coluna numérica para `float32` ou `int32` e verifique a réduction do uso de memória.

# %%
# Seu código aqui
import pandas as pd

df_big = pd.read_csv("../../data/aula_02/batch_data/big_file.csv")

df_big.info(memory_usage="deep")

df_big["A"] = df_big["A"].astype("int32")

df_big.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       50000 non-null  int64
#  1   B       50000 non-null  int64
#  2   C       50000 non-null  int64
#  3   D       50000 non-null  int64
#  4   E       50000 non-null  int64
# dtypes: int64(5)
# memory usage: 1.9 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       50000 non-null  int32
#  1   B       50000 non-null  int64
#  2   C       50000 non-null  int64
#  3   D       50000 non-null  int64
#  4   E       50000 non-null  int64
# dtypes: int32(1), int64(4)
# memory usage: 1.7 MB

# %% [markdown]
# ## 11. Extração com Regex
# Suponha a seguinte coluna de texto sujo. Crie um DataFrame com ela e use `str.extract` para obter apenas o código numérico.
# ```python
# dados = {'Info': ['Produto: [123] - Vendido', 'Produto: [456] - Estoque', 'Produto: [789] - Devolvido']}
# ```

# %%
# Seu código aqui
import pandas as pd

dados = {
    'Info': [
        'Produto: [123] - Vendido',
        'Produto: [456] - Estoque',
        'Produto: [789] - Devolvido'
    ]
}

df = pd.DataFrame(dados)
df["Codigo"] = df["Info"].str.extract(r"\[(\d+)\]")

df
# Out:
#                          Info Codigo
# 0    Produto: [123] - Vendido    123
# 1    Produto: [456] - Estoque    456
# 2  Produto: [789] - Devolvido    789

# %% [markdown]
# ---
# ## 12. DESAFIO PARA CASA (Real Data)
# 1. Entre no site [dados.gov.br](https://dados.gov.br) ou [Kaggle](https://kaggle.com).
# 2. Baixe um dataset CSV de seu interesse (tamanho mínimo: 1000 linhas).
# 3. Carregue-o no pandas, tratando problemas de encoding/separador se houver.
# 4. Exiba um `.info()` e `.describe()`.
# 5. Responda: Qual o tamanho do arquivo em memória?

# %%
import pandas as pd
import requests

url = "https://servicodados.ibge.gov.br/api/v1/localidades/municipios"

response = requests.get(url)
dados = response.json()

df = pd.json_normalize(dados)

df.info(memory_usage="deep")
df.describe(include="all")

memoria = df.memory_usage(deep=True).sum()
print(f"Tamanho em memória: {memoria} bytes")
print(f"Tamanho em memória: {memoria / 1024:.2f} KB")
print(f"Tamanho em memória: {memoria / (1024**2):.2f} MB")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5571 entries, 0 to 5570
# Data columns (total 23 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   id                                                    5571 non-null   int64
#  1   nome                                                  5571 non-null   object
#  2   microrregiao.id                                       5570 non-null   float64
#  3   microrregiao.nome                                     5570 non-null   object
#  4   microrregiao.mesorregiao.id                           5570 non-null   float64
#  5   microrregiao.mesorregiao.nome                         5570 non-null   object
#  6   microrregiao.mesorregiao.UF.id                        5570 non-null   float64
#  7   microrregiao.mesorregiao.UF.sigla                     5570 non-null   object
#  8   microrregiao.mesorregiao.UF.nome                      5570 non-null   object
#  9   microrregiao.mesorregiao.UF.regiao.id                 5570 non-null   float64
#  10  microrregiao.mesorregiao.UF.regiao.sigla              5570 non-null   object
#  11  microrregiao.mesorregiao.UF.regiao.nome               5570 non-null   object
#  12  regiao-imediata.id                                    5571 non-null   int64
#  13  regiao-imediata.nome                                  5571 non-null   object
#  14  regiao-imediata.regiao-intermediaria.id               5571 non-null   int64
#  15  regiao-imediata.regiao-intermediaria.nome             5571 non-null   object
#  16  regiao-imediata.regiao-intermediaria.UF.id            5571 non-null   int64
#  17  regiao-imediata.regiao-intermediaria.UF.sigla         5571 non-null   object
#  18  regiao-imediata.regiao-intermediaria.UF.nome          5571 non-null   object
#  19  regiao-imediata.regiao-intermediaria.UF.regiao.id     5571 non-null   int64
#  20  regiao-imediata.regiao-intermediaria.UF.regiao.sigla  5571 non-null   object
#  21  regiao-imediata.regiao-intermediaria.UF.regiao.nome   5571 non-null   object
#  22  microrregiao                                          0 non-null      float64
# dtypes: float64(5), int64(5), object(13)
# memory usage: 4.6 MB
# Tamanho em memória: 4812820 bytes
# Tamanho em memória: 4700.02 KB
# Tamanho em memória: 4.59 MB
