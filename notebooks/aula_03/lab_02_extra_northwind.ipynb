# %% [markdown]
# # Lab 02 Extra - Banco de Dados Northwind
# **Disciplina:** Extração e Preparação de Dados | **Professor:** Luis Aramis
#
# Este é um notebook extra para praticar SQL com um banco de dados clássico: o **Northwind**.
# Ele simula uma importadora/exportadora de alimentos gourmet.

# %% [markdown]
# ## 1. Setup e Download
# Vamos baixar o `northwind.db` e conectar o SQLAlchemy.

# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import urllib.request

# Download do northwind.db
if not os.path.exists('northwind.db'):
    # URL do repositório jpwhite3/northwind-SQLite3
    url = 'https://github.com/jpwhite3/northwind-SQLite3/raw/main/dist/northwind.db'
    urllib.request.urlretrieve(url, 'northwind.db')
    print('Banco Northwind baixado com sucesso!')

engine = create_engine('sqlite:///northwind.db')
print('Conexão estabelecida!')
# Out:
# Conexão estabelecida!

# %% [markdown]
# ## 2. Mapa do Banco
# Quais tabelas temos aqui?

# %%
query = "SELECT name FROM sqlite_master WHERE type='table';"
pd.read_sql(query, engine)
# Out:
#                     name
# 0             Categories
# 1        sqlite_sequence
# 2   CustomerCustomerDemo
# 3   CustomerDemographics
# 4              Customers
# 5              Employees
# 6    EmployeeTerritories
# 7          Order Details
# 8                 Orders
# 9               Products
# 10               Regions
# 11              Shippers
# 12             Suppliers
# 13           Territories

# %% [markdown]
# ## 3. Consultas Básicas
# 1. Liste os 5 produtos mais caros (`Products`).
# 2. Liste todos os clientes (`Customers`) que moram no 'Brazil'.

# %%
# Produtos mais caros
query_produtos = """
SELECT ProductName, UnitPrice
FROM Products
ORDER BY UnitPrice DESC
LIMIT 5;
"""

top_5_produtos = pd.read_sql(query_produtos, engine)
top_5_produtos
# Out:
#                ProductName  UnitPrice
# 0            Côte de Blaye     263.50
# 1  Thüringer Rostbratwurst     123.79
# 2          Mishi Kobe Niku      97.00
# 3   Sir Rodney's Marmalade      81.00
# 4         Carnarvon Tigers      62.50

# %%
# Clientes do Brasil
query_clientes = """
SELECT *
FROM Customers
WHERE Country = 'Brazil';
"""

clientes_brasil = pd.read_sql(query_clientes, engine)
clientes_brasil
# Out:
#   CustomerID             CompanyName        ContactName  \
# 0      COMMI        Comércio Mineiro       Pedro Afonso
# 1      FAMIA      Familia Arquibaldo          Aria Cruz
# 2      GOURL     Gourmet Lanchonetes      André Fonseca
# 3      HANAR           Hanari Carnes       Mario Pontes
# 4      QUEDE             Que Delícia   Bernardo Batista
# 5      QUEEN           Queen Cozinha     Lúcia Carvalho
# 6      RICAR      Ricardo Adocicados     Janete Limeira
# 7      TRADH  Tradição Hipermercados  Anabela Domingues
# 8      WELLI  Wellington Importadora      Paula Parente
#
#             ContactTitle                    Address            City  \
# 0        Sales Associate       Av. dos Lusíadas, 23       Sao Paulo
# 1    Marketing Assistant               Rua Orós, 92       Sao Paulo
# 2        Sales Associate            Av. Brasil, 442        Campinas
# 3     Accounting Manager            Rua do Paço, 67  Rio de Janeiro
# 4     Accounting Manager    Rua da Panificadora, 12  Rio de Janeiro
# 5    Marketing Assistant  Alameda dos Canàrios, 891       Sao Paulo
# 6  Assistant Sales Agent        Av. Copacabana, 267  Rio de Janeiro
# 7   Sales Representative    Av. Inês de Castro, 414       Sao Paulo
# 8          Sales Manager         Rua do Mercado, 12         Resende
#
#           Region PostalCode Country          Phone            Fax
# 0  South America  05432-043  Brazil  (11) 555-7647           None
# 1  South America  05442-030  Brazil  (11) 555-9857           None
# 2  South America  04876-786  Brazil  (11) 555-9482           None
# 3  South America  05454-876  Brazil  (21) 555-0091  (21) 555-8765
# 4  South America  02389-673  Brazil  (21) 555-4252  (21) 555-4545
# 5  South America  05487-020  Brazil  (11) 555-1189           None
# 6  South America  02389-890  Brazil  (21) 555-3412           None
# 7  South America  05634-030  Brazil  (11) 555-2167  (11) 555-2168
# 8  South America  08737-363  Brazil  (14) 555-8122           None

# %% [markdown]
# ## 4. JOIN: Pedidos e Clientes
# Vamos ver quem fez quais pedidos.
# Tabelas: `Orders` e `Customers`.
# Chave de ligação: `CustomerID`.

# %%
query = """
SELECT o.OrderID, o.OrderDate, c.CustomerID, c.CompanyName, c.Country
FROM Orders o
JOIN Customers c
    ON o.CustomerID = c.CustomerID;
"""

pedidos_clientes = pd.read_sql(query, engine)
pedidos_clientes.head()
# Out:
#    OrderID   OrderDate CustomerID                CompanyName  Country
# 0    10248  2016-07-04      VINET  Vins et alcools Chevalier   France
# 1    10249  2016-07-05      TOMSP         Toms Spezialitäten  Germany
# 2    10250  2016-07-08      HANAR              Hanari Carnes   Brazil
# 3    10251  2016-07-08      VICTE       Victuailles en stock   France
# 4    10252  2016-07-09      SUPRD           Suprêmes délices  Belgium

# %% [markdown]
# ## 5. JOIN Triplo: Detalhes do Pedido
# O que tem dentro do pedido 10248?
# Caminho: `OrderDetails` -> `Products`.

# %%
query = """
SELECT od.OrderID, od.ProductID, p.ProductName, od.Quantity, od.UnitPrice
FROM [Order Details] od
JOIN Products p
    ON od.ProductID = p.ProductID
WHERE od.OrderID = 10248;
"""

pedido_10248 = pd.read_sql(query, engine)
pedido_10248
# Out:
#    OrderID  ProductID                    ProductName  Quantity  UnitPrice
# 0    10248         11                 Queso Cabrales        12       14.0
# 1    10248         42  Singaporean Hokkien Fried Mee        10        9.8
# 2    10248         72         Mozzarella di Giovanni         5       34.8

# %% [markdown]
# ## 6. Desafio: Total de Vendas por Categoria
# Descubra qual Categoria de produtos (`Categories`) gerou mais receita.
# Dica: Você vai precisar ligar `Categories` -> `Products` -> `Order Details`.

# %%
# Seu código aqui
query = """
SELECT c.CategoryName, SUM(od.UnitPrice * od.Quantity) AS ReceitaTotal
FROM Categories c
JOIN Products p
    ON c.CategoryID = p.CategoryID
JOIN [Order Details] od
    ON p.ProductID = od.ProductID
GROUP BY c.CategoryName
ORDER BY ReceitaTotal DESC;
"""

vendas_categoria = pd.read_sql(query, engine)
vendas_categoria
# Out:
#      CategoryName  ReceitaTotal
# 0       Beverages   92181842.95
# 1     Confections   66347544.94
# 2    Meat/Poultry   64896314.41
# 3  Dairy Products   58034940.00
# 4      Condiments   55802774.45
# 5         Seafood   49931965.52
# 6         Produce   32706403.90
# 7  Grains/Cereals   28573512.55
